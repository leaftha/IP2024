# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('./Contours/20241028_122740.png')
edges100 = cv2.Canny(img,100,100)

# %%
contours, hierarchy = cv2.findContours(edges100,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
img0 = img.copy()
img1 = cv2.drawContours(img0, contours, -1, (255,0,255), 5)
plt.subplot(1,2,1),plt.imshow(img)
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,2,2),plt.imshow(img1)
plt.title('contours'), plt.xticks([]), plt.yticks([])
# Out:
# (Text(0.5, 1.0, 'contours'), ([], []), ([], []))

# %%
import cv2
import numpy as np
img = cv2.imread('./Contours/Canopic-Jar.png',0)
ret,thresh = cv2.threshold(img,127,255,0)
contours,hierarchy = cv2.findContours(thresh, 1, 2)
cnt = contours[0]
M = cv2.moments(cnt)
print(M)
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[59], line 6
#       4 ret,thresh = cv2.threshold(img,127,255,0)
#       5 contours,hierarchy = cv2.findContours(thresh, 1, 2)
# ----> 6 cnt = contours[0]
#       7 M = cv2.moments(cnt)
#       8 print(M)
#
# IndexError: tuple index out of range

# %%
area = cv2.contourArea(cnt)
perimeter = cv2.arcLength(cnt,True)
epsilon = 0.1*cv2.arcLength(cnt,True)
approx = cv2.approxPolyDP(cnt,epsilon,True)
hull = cv2.convexHull(cnt)
k = cv2.isContourConvex(cnt)
x,y,w,h = cv2.boundingRect(cnt)
img = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
rect = cv2.minAreaRect(cnt)
box = cv2.boxPoints(rect)
box = np.int0(box)
im = cv2.drawContours(img,[box],0,(0,0,255),2)
(x,y),radius = cv2.minEnclosingCircle(cnt)
center = (int(x),int(y))
radius = int(radius)
img = cv2.circle(img,center,radius,(0,255,0),2)
ellipse = cv2.fitEllipse(cnt)
im = cv2.ellipse(im,ellipse,(0,255,0),2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 area = cv2.contourArea(cnt)
#       2 perimeter = cv2.arcLength(cnt,True)
#       3 epsilon = 0.1*cv2.arcLength(cnt,True)
#
# NameError: name 'cv2' is not defined
