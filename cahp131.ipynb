# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("cat.jpg")
plt.imshow(img,cmap="gray", interpolation="bicubic")
plt.xticks([]),plt.yticks([])
plt.show()

# %%
img[200,100] = [0,0,0]
plt.imshow(img,cmap="gray", interpolation="bicubic")
plt.xticks([]),plt.yticks([])
plt.show()

# %%
# img[:100,:100] = [0,0,0]
# plt.imshow(img,cmap="gray", interpolation="bicubic")
# plt.show()

# %%
# img[100:1000,600:900,2:200] = 144
# plt.imshow(img,cmap="gray", interpolation="bicubic")
# plt.show()

# %%
plt_img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
face = img[0:300,400:800]
img[0:300,0:200] = face

plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 3
#       1 plt_img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
#       2 face = img[0:300,400:800]
# ----> 3 img[0:300,0:200] = face
#       5 plt.imshow(img)
#       6 plt.show()
#
# ValueError: could not broadcast input array from shape (300,400,3) into shape (300,200,3)
